# %% [markdown]
# <a href="https://colab.research.google.com/github/SomtoNnajide/Colab-projects/blob/Colab-branch/Somto_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Plotting the raw data

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
iris = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/639388c2cbc2120a14dcf466e85730eb8be498bb/iris.csv")
iris.plot()

# %%
#plt.style.available

# %% [markdown]
# ## Visulaizing data in table format

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Generic scatterplot of data

# %%
iris.plot('sepal_length', 'sepal_width', kind = 'scatter');

# %% [markdown]
# ## Defined scatterplot

# %%
warnings.filterwarnings("ignore")

#fig, ax = plt.subplots()
iris.plot.scatter('sepal_length', 'sepal_width', c='petal_length', s=20, colormap = 'plasma')#ax=ax)
